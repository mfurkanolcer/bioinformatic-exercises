# %% [markdown]
# ## Snap.py
# Snap.py, SNAP için bir Python arabirimidir. SNAP, büyük ağların analizi ve manipülasyonu için genel amaçlı, yüksek performanslı bir sistemdir.

# %% [markdown]
# ### Grafik ve Ağ Türleri:
# Snap.py grafikleri ve ağları destekler. Grafikler topolojileri tanımlar. Bu, benzersiz tamsayı kimliklerine ve grafiğin düğümleri arasında yönlendirilmiş/yönlendirilmemiş/çoklu kenarlara sahip düğümlerdir. Ağlar, ağın düğümleri ve/veya kenarları hakkında veri içeren grafiklerdir. Düğümlerde ve kenarlarda bulunan veri türleri, düğümlerde ve uçlarda zengin veriler içeren çeşitli ağ türlerini uygulamanın çok hızlı ve kolay bir yolunu sağlayan şablon parametreleri olarak geçirilir.

# %% [markdown]
# #### Grafik Tipleri:
#
# TUNGraph: yönlendirilmemiş grafik (sırasız bir düğüm çifti arasındaki tek kenar)
#
# TNGraph: yönlendirilmiş grafik (sıralı bir düğüm çifti arasında tek yönlendirilmiş kenar)

# %% [markdown]
# #### Ağ Tipleri:
#
# TNENet: düğümler ve kenarlar için niteliklere sahip yönlendirilmiş çoklu grafik

# %% [markdown]
# ---

# %% [markdown]
# ### Grafik Oluşturma:
#
# Düğümlerin açık (ve isteğe bağlı) düğüm kimlikleri vardır. Düğüm kimliklerinin 0'dan başlayan bitişik tamsayılar olması için herhangi bir kısıtlama yoktur. TUNGraph ve TNGraph'ta kenarların açık kimlikleri yoktur, kenarlar bir çift düğüm kimliği tarafından tanımlanır.
#
# Ağlar, grafiklerle aynı şekilde oluşturulur.

# %%
import snap

# %%
G1 = snap.TNGraph.New()

G1.AddNode(1)
G1.AddNode(5)
G1.AddNode(32)
G1.AddEdge(1,5)
G1.AddEdge(5,1)
G1.AddEdge(5,32)

print(G1.GetNodes(), G1.GetEdges() )
# Out:
# 3 3

# %% [markdown]
# ---

# %% [markdown]
# ### Yineleyiciler:
#
# Birçok SNAP işlemi, türüne (yönlendirilmiş, yönlendirilmemiş, grafikler, ağlar) ve belirli uygulamaya bakılmaksızın ağlarda çalışan algoritmaların verimli bir şekilde uygulanmasına izin veren düğüm ve uç yineleyicilere dayanır.
#
# Snap.py'de yineleyici kullanımının bazı örnekleri aşağıda gösterilmiştir:

# %%
# 100 dugum ve 1k kenarda yonlendirilmis rastgele bir grafik olustur
G2 = snap.GenRndGnm(snap.TNGraph, 100, 1000)

# %%
# dugumleri caprazla
for NI in G2.Nodes():
    print("node id %d with out-degree %d and in-degree %d" % (
        NI.GetId(), NI.GetOutDeg(), NI.GetInDeg()))
# Out:
# node id 0 with out-degree 13 and in-degree 9
# node id 1 with out-degree 8 and in-degree 10
# node id 2 with out-degree 14 and in-degree 15
# node id 3 with out-degree 14 and in-degree 10
# node id 4 with out-degree 11 and in-degree 4
# node id 5 with out-degree 12 and in-degree 6
# node id 6 with out-degree 11 and in-degree 12
# node id 7 with out-degree 11 and in-degree 11
# node id 8 with out-degree 8 and in-degree 10
# node id 9 with out-degree 8 and in-degree 9
# node id 10 with out-degree 7 and in-degree 6
# node id 11 with out-degree 6 and in-degree 6
# node id 12 with out-degree 11 and in-degree 10
# node id 13 with out-degree 9 and in-degree 7
# node id 14 with out-degree 9 and in-degree 13
# node id 15 with out-degree 11 and in-degree 10
# node id 16 with out-degree 11 and in-degree 11
# node id 17 with out-degree 7 and in-degree 7
# node id 18 with out-degree 8 and in-degree 11
# node id 19 with out-degree 11 and in-degree 9
# node id 20 with out-degree 13 and in-degree 11
# node id 21 with out-degree 13 and in-degree 7
# node id 22 with out-degree 11 and in-degree 8
# node id 23 with out-degree 8 and in-degree 5
# node id 24 with out-degree 9 and in-degree 10
# node id 25 with out-degree 10 and in-degree 8
# node id 26 with out-degree 8 and in-degree 8
# node id 27 with out-degree 13 and in-degree 5
# node id 28 with out-degree 9 and in-degree 10
# node id 29 with out-degree 7 and in-degree 12
# node id 30 with out-degree 3 and in-degree 9
# node id 31 with out-degree 12 and in-degree 4
# node id 32 with out-degree 17 and in-degree 14
# node id 33 with out-degree 9 and in-degree 12
# node id 34 with out-degree 14 and in-degree 12
# node id 35 with out-degree 10 and in-degree 6
# node id 36 with out-degree 8 and in-degree 7
# node id 37 with out-degree 13 and in-degree 12
# node id 38 with out-degree 5 and in-degree 10
# node id 39 with out-degree 18 and in-degree 16
# node id 40 with out-degree 8 and in-degree 13
# node id 41 with out-degree 6 and in-degree 10
# node id 42 with out-degree 10 and in-degree 10
# node id 43 with out-degree 3 and in-degree 10
# node id 44 with out-degree 6 and in-degree 11
# node id 45 with out-degree 16 and in-degree 7
# node id 46 with out-degree 8 and in-degree 7
# node id 47 with out-degree 9 and in-degree 12
# node id 48 with out-degree 16 and in-degree 16
# node id 49 with out-degree 10 and in-degree 10
# node id 50 with out-degree 15 and in-degree 10
# node id 51 with out-degree 6 and in-degree 9
# node id 52 with out-degree 14 and in-degree 10
# node id 53 with out-degree 15 and in-degree 9
# node id 54 with out-degree 9 and in-degree 12
# node id 55 with out-degree 7 and in-degree 8
# node id 56 with out-degree 8 and in-degree 9
# node id 57 with out-degree 11 and in-degree 14
# node id 58 with out-degree 14 and in-degree 6
# node id 59 with out-degree 5 and in-degree 7
# node id 60 with out-degree 8 and in-degree 5
# node id 61 with out-degree 5 and in-degree 17
# node id 62 with out-degree 9 and in-degree 8
# node id 63 with out-degree 9 and in-degree 8
# node id 64 with out-degree 10 and in-degree 5
# node id 65 with out-degree 8 and in-degree 13
# node id 66 with out-degree 13 and in-degree 16
# node id 67 with out-degree 5 and in-degree 9
# node id 68 with out-degree 12 and in-degree 10
# node id 69 with out-degree 8 and in-degree 13
# node id 70 with out-degree 6 and in-degree 9
# node id 71 with out-degree 9 and in-degree 13
# node id 72 with out-degree 11 and in-degree 11
# node id 73 with out-degree 11 and in-degree 10
# node id 74 with out-degree 13 and in-degree 7
# node id 75 with out-degree 10 and in-degree 9
# node id 76 with out-degree 11 and in-degree 11
# node id 77 with out-degree 13 and in-degree 11
# node id 78 with out-degree 9 and in-degree 9
# node id 79 with out-degree 7 and in-degree 17
# node id 80 with out-degree 12 and in-degree 11
# node id 81 with out-degree 5 and in-degree 5
# node id 82 with out-degree 8 and in-degree 8
# node id 83 with out-degree 11 and in-degree 11
# node id 84 with out-degree 9 and in-degree 10
# node id 85 with out-degree 12 and in-degree 18
# node id 86 with out-degree 4 and in-degree 11
# node id 87 with out-degree 9 and in-degree 14
# node id 88 with out-degree 10 and in-degree 9
# node id 89 with out-degree 13 and in-degree 10
# node id 90 with out-degree 10 and in-degree 10
# node id 91 with out-degree 15 and in-degree 10
# node id 92 with out-degree 18 and in-degree 7
# node id 93 with out-degree 8 and in-degree 13
# node id 94 with out-degree 12 and in-degree 7
# node id 95 with out-degree 10 and in-degree 12
# node id 96 with out-degree 12 and in-degree 17
# node id 97 with out-degree 11 and in-degree 10
# node id 98 with out-degree 5 and in-degree 14
# node id 99 with out-degree 13 and in-degree 10

# %%
# kenarlari caprazla
for EI in G2.Edges():
    print("edge (%d, %d)" % (EI.GetSrcNId(), EI.GetDstNId()))
# Out:
# edge (0, 24)
# edge (0, 37)
# edge (0, 40)
# edge (0, 41)
# edge (0, 44)
# edge (0, 48)
# edge (0, 84)
# edge (0, 87)
# edge (0, 90)
# edge (0, 91)
# edge (0, 94)
# edge (0, 95)
# edge (0, 96)
# edge (1, 2)
# edge (1, 35)
# edge (1, 56)
# edge (1, 66)
# edge (1, 83)
# edge (1, 85)
# edge (1, 90)
# edge (1, 95)
# edge (2, 0)
# edge (2, 10)
# edge (2, 13)
# edge (2, 26)
# edge (2, 34)
# edge (2, 43)
# edge (2, 46)
# edge (2, 65)
# edge (2, 75)
# edge (2, 79)
# edge (2, 88)
# edge (2, 89)
# edge (2, 91)
# edge (2, 92)
# edge (3, 16)
# edge (3, 29)
# edge (3, 32)
# edge (3, 33)
# edge (3, 41)
# edge (3, 53)
# edge (3, 62)
# edge (3, 70)
# edge (3, 72)
# edge (3, 77)
# edge (3, 82)
# edge (3, 89)
# edge (3, 92)
# edge (3, 98)
# edge (4, 13)
# edge (4, 18)
# edge (4, 22)
# edge (4, 25)
# edge (4, 40)
# edge (4, 62)
# edge (4, 68)
# edge (4, 79)
# edge (4, 85)
# edge (4, 86)
# edge (4, 88)
# edge (5, 0)
# edge (5, 24)
# edge (5, 29)
# edge (5, 33)
# edge (5, 34)
# edge (5, 50)
# edge (5, 54)
# edge (5, 62)
# edge (5, 71)
# edge (5, 96)
# edge (5, 97)
# edge (5, 99)
# edge (6, 34)
# edge (6, 42)
# edge (6, 57)
# edge (6, 63)
# edge (6, 68)
# edge (6, 73)
# edge (6, 77)
# edge (6, 85)
# edge (6, 87)
# edge (6, 95)
# edge (6, 96)
# edge (7, 8)
# edge (7, 34)
# edge (7, 36)
# edge (7, 43)
# edge (7, 53)
# edge (7, 61)
# edge (7, 62)
# edge (7, 71)
# edge (7, 78)
# edge (7, 85)
# edge (7, 99)
# edge (8, 21)
# edge (8, 36)
# edge (8, 39)
# edge (8, 54)
# edge (8, 59)
# edge (8, 67)
# edge (8, 79)
# edge (8, 87)
# edge (9, 17)
# edge (9, 29)
# edge (9, 39)
# edge (9, 41)
# edge (9, 45)
# edge (9, 48)
# edge (9, 77)
# edge (9, 91)
# edge (10, 24)
# edge (10, 29)
# edge (10, 39)
# edge (10, 40)
# edge (10, 47)
# edge (10, 76)
# edge (10, 92)
# edge (11, 2)
# edge (11, 49)
# edge (11, 53)
# edge (11, 59)
# edge (11, 65)
# edge (11, 76)
# edge (12, 1)
# edge (12, 2)
# edge (12, 8)
# edge (12, 20)
# edge (12, 36)
# edge (12, 46)
# edge (12, 61)
# edge (12, 74)
# edge (12, 85)
# edge (12, 86)
# edge (12, 95)
# edge (13, 14)
# edge (13, 42)
# edge (13, 46)
# edge (13, 53)
# edge (13, 55)
# edge (13, 57)
# edge (13, 69)
# edge (13, 91)
# edge (13, 98)
# edge (14, 1)
# edge (14, 3)
# edge (14, 34)
# edge (14, 37)
# edge (14, 54)
# edge (14, 57)
# edge (14, 66)
# edge (14, 78)
# edge (14, 79)
# edge (15, 7)
# edge (15, 8)
# edge (15, 16)
# edge (15, 22)
# edge (15, 36)
# edge (15, 40)
# edge (15, 45)
# edge (15, 48)
# edge (15, 65)
# edge (15, 96)
# edge (15, 97)
# edge (16, 14)
# edge (16, 15)
# edge (16, 21)
# edge (16, 29)
# edge (16, 37)
# edge (16, 42)
# edge (16, 48)
# edge (16, 62)
# edge (16, 73)
# edge (16, 78)
# edge (16, 96)
# edge (17, 2)
# edge (17, 6)
# edge (17, 19)
# edge (17, 39)
# edge (17, 40)
# edge (17, 61)
# edge (17, 72)
# edge (18, 0)
# edge (18, 11)
# edge (18, 17)
# edge (18, 20)
# edge (18, 32)
# edge (18, 76)
# edge (18, 80)
# edge (18, 86)
# edge (19, 1)
# edge (19, 7)
# edge (19, 23)
# edge (19, 25)
# edge (19, 26)
# edge (19, 38)
# edge (19, 66)
# edge (19, 70)
# edge (19, 72)
# edge (19, 79)
# edge (19, 93)
# edge (20, 2)
# edge (20, 13)
# edge (20, 28)
# edge (20, 32)
# edge (20, 37)
# edge (20, 46)
# edge (20, 53)
# edge (20, 59)
# edge (20, 78)
# edge (20, 79)
# edge (20, 80)
# edge (20, 92)
# edge (20, 94)
# edge (21, 0)
# edge (21, 2)
# edge (21, 8)
# edge (21, 18)
# edge (21, 40)
# edge (21, 47)
# edge (21, 48)
# edge (21, 50)
# edge (21, 51)
# edge (21, 56)
# edge (21, 70)
# edge (21, 73)
# edge (21, 83)
# edge (22, 1)
# edge (22, 2)
# edge (22, 7)
# edge (22, 9)
# edge (22, 19)
# edge (22, 24)
# edge (22, 30)
# edge (22, 71)
# edge (22, 75)
# edge (22, 87)
# edge (22, 92)
# edge (23, 39)
# edge (23, 43)
# edge (23, 51)
# edge (23, 52)
# edge (23, 75)
# edge (23, 84)
# edge (23, 88)
# edge (23, 98)
# edge (24, 8)
# edge (24, 10)
# edge (24, 41)
# edge (24, 56)
# edge (24, 68)
# edge (24, 76)
# edge (24, 77)
# edge (24, 80)
# edge (24, 98)
# edge (25, 2)
# edge (25, 16)
# edge (25, 24)
# edge (25, 29)
# edge (25, 47)
# edge (25, 50)
# edge (25, 55)
# edge (25, 75)
# edge (25, 80)
# edge (25, 98)
# edge (26, 14)
# edge (26, 15)
# edge (26, 20)
# edge (26, 54)
# edge (26, 68)
# edge (26, 70)
# edge (26, 79)
# edge (26, 88)
# edge (27, 1)
# edge (27, 3)
# edge (27, 8)
# edge (27, 28)
# edge (27, 29)
# edge (27, 32)
# edge (27, 33)
# edge (27, 47)
# edge (27, 49)
# edge (27, 57)
# edge (27, 60)
# edge (27, 70)
# edge (27, 92)
# edge (28, 1)
# edge (28, 13)
# edge (28, 18)
# edge (28, 21)
# edge (28, 29)
# edge (28, 42)
# edge (28, 74)
# edge (28, 87)
# edge (28, 99)
# edge (29, 15)
# edge (29, 52)
# edge (29, 54)
# edge (29, 81)
# edge (29, 90)
# edge (29, 96)
# edge (29, 99)
# edge (30, 38)
# edge (30, 61)
# edge (30, 85)
# edge (31, 0)
# edge (31, 7)
# edge (31, 9)
# edge (31, 21)
# edge (31, 23)
# edge (31, 25)
# edge (31, 42)
# edge (31, 50)
# edge (31, 67)
# edge (31, 77)
# edge (31, 83)
# edge (31, 86)
# edge (32, 11)
# edge (32, 19)
# edge (32, 30)
# edge (32, 37)
# edge (32, 41)
# edge (32, 44)
# edge (32, 49)
# edge (32, 50)
# edge (32, 51)
# edge (32, 55)
# edge (32, 60)
# edge (32, 61)
# edge (32, 83)
# edge (32, 85)
# edge (32, 91)
# edge (32, 93)
# edge (32, 97)
# edge (33, 7)
# edge (33, 22)
# edge (33, 35)
# edge (33, 40)
# edge (33, 41)
# edge (33, 53)
# edge (33, 80)
# edge (33, 89)
# edge (33, 98)
# edge (34, 1)
# edge (34, 2)
# edge (34, 7)
# edge (34, 20)
# edge (34, 43)
# edge (34, 44)
# edge (34, 57)
# edge (34, 63)
# edge (34, 64)
# edge (34, 69)
# edge (34, 86)
# edge (34, 87)
# edge (34, 88)
# edge (34, 93)
# edge (35, 18)
# edge (35, 24)
# edge (35, 26)
# edge (35, 27)
# edge (35, 30)
# edge (35, 45)
# edge (35, 65)
# edge (35, 66)
# edge (35, 72)
# edge (35, 79)
# edge (36, 14)
# edge (36, 20)
# edge (36, 32)
# edge (36, 42)
# edge (36, 50)
# edge (36, 52)
# edge (36, 71)
# edge (36, 99)
# edge (37, 9)
# edge (37, 16)
# edge (37, 22)
# edge (37, 23)
# edge (37, 30)
# edge (37, 32)
# edge (37, 47)
# edge (37, 63)
# edge (37, 66)
# edge (37, 67)
# edge (37, 71)
# edge (37, 79)
# edge (37, 91)
# edge (38, 32)
# edge (38, 34)
# edge (38, 36)
# edge (38, 67)
# edge (38, 93)
# edge (39, 9)
# edge (39, 12)
# edge (39, 18)
# edge (39, 28)
# edge (39, 38)
# edge (39, 42)
# edge (39, 44)
# edge (39, 48)
# edge (39, 53)
# edge (39, 54)
# edge (39, 58)
# edge (39, 61)
# edge (39, 65)
# edge (39, 66)
# edge (39, 70)
# edge (39, 83)
# edge (39, 95)
# edge (39, 97)
# edge (40, 2)
# edge (40, 6)
# edge (40, 21)
# edge (40, 34)
# edge (40, 58)
# edge (40, 72)
# edge (40, 84)
# edge (40, 85)
# edge (41, 40)
# edge (41, 43)
# edge (41, 44)
# edge (41, 53)
# edge (41, 89)
# edge (41, 96)
# edge (42, 0)
# edge (42, 5)
# edge (42, 6)
# edge (42, 14)
# edge (42, 18)
# edge (42, 20)
# edge (42, 26)
# edge (42, 40)
# edge (42, 56)
# edge (42, 76)
# edge (43, 16)
# edge (43, 30)
# edge (43, 79)
# edge (44, 12)
# edge (44, 64)
# edge (44, 68)
# edge (44, 69)
# edge (44, 72)
# edge (44, 97)
# edge (45, 3)
# edge (45, 10)
# edge (45, 18)
# edge (45, 19)
# edge (45, 24)
# edge (45, 26)
# edge (45, 32)
# edge (45, 34)
# edge (45, 41)
# edge (45, 46)
# edge (45, 63)
# edge (45, 79)
# edge (45, 80)
# edge (45, 82)
# edge (45, 85)
# edge (45, 90)
# edge (46, 7)
# edge (46, 16)
# edge (46, 39)
# edge (46, 47)
# edge (46, 63)
# edge (46, 69)
# edge (46, 80)
# edge (46, 85)
# edge (47, 33)
# edge (47, 38)
# edge (47, 43)
# edge (47, 46)
# edge (47, 65)
# edge (47, 72)
# edge (47, 78)
# edge (47, 91)
# edge (47, 96)
# edge (48, 3)
# edge (48, 5)
# edge (48, 14)
# edge (48, 17)
# edge (48, 33)
# edge (48, 50)
# edge (48, 51)
# edge (48, 54)
# edge (48, 66)
# edge (48, 70)
# edge (48, 71)
# edge (48, 76)
# edge (48, 77)
# edge (48, 84)
# edge (48, 96)
# edge (48, 98)
# edge (49, 12)
# edge (49, 20)
# edge (49, 27)
# edge (49, 35)
# edge (49, 39)
# edge (49, 61)
# edge (49, 75)
# edge (49, 76)
# edge (49, 87)
# edge (49, 96)
# edge (50, 6)
# edge (50, 12)
# edge (50, 19)
# edge (50, 25)
# edge (50, 32)
# edge (50, 37)
# edge (50, 44)
# edge (50, 57)
# edge (50, 61)
# edge (50, 69)
# edge (50, 80)
# edge (50, 90)
# edge (50, 95)
# edge (50, 98)
# edge (50, 99)
# edge (51, 33)
# edge (51, 39)
# edge (51, 75)
# edge (51, 76)
# edge (51, 81)
# edge (51, 95)
# edge (52, 1)
# edge (52, 14)
# edge (52, 27)
# edge (52, 30)
# edge (52, 33)
# edge (52, 37)
# edge (52, 44)
# edge (52, 51)
# edge (52, 59)
# edge (52, 66)
# edge (52, 67)
# edge (52, 74)
# edge (52, 85)
# edge (52, 98)
# edge (53, 5)
# edge (53, 22)
# edge (53, 28)
# edge (53, 34)
# edge (53, 45)
# edge (53, 48)
# edge (53, 49)
# edge (53, 56)
# edge (53, 57)
# edge (53, 61)
# edge (53, 66)
# edge (53, 69)
# edge (53, 71)
# edge (53, 85)
# edge (53, 90)
# edge (54, 10)
# edge (54, 33)
# edge (54, 41)
# edge (54, 45)
# edge (54, 49)
# edge (54, 51)
# edge (54, 76)
# edge (54, 82)
# edge (54, 96)
# edge (55, 8)
# edge (55, 19)
# edge (55, 41)
# edge (55, 49)
# edge (55, 50)
# edge (55, 60)
# edge (55, 77)
# edge (56, 6)
# edge (56, 12)
# edge (56, 51)
# edge (56, 59)
# edge (56, 68)
# edge (56, 75)
# edge (56, 82)
# edge (56, 89)
# edge (57, 8)
# edge (57, 28)
# edge (57, 37)
# edge (57, 42)
# edge (57, 48)
# edge (57, 61)
# edge (57, 75)
# edge (57, 78)
# edge (57, 85)
# edge (57, 94)
# edge (57, 97)
# edge (58, 5)
# edge (58, 6)
# edge (58, 9)
# edge (58, 11)
# edge (58, 15)
# edge (58, 16)
# edge (58, 19)
# edge (58, 55)
# edge (58, 63)
# edge (58, 64)
# edge (58, 69)
# edge (58, 91)
# edge (58, 95)
# edge (58, 98)
# edge (59, 28)
# edge (59, 32)
# edge (59, 37)
# edge (59, 38)
# edge (59, 47)
# edge (60, 14)
# edge (60, 17)
# edge (60, 22)
# edge (60, 26)
# edge (60, 57)
# edge (60, 69)
# edge (60, 85)
# edge (60, 86)
# edge (61, 0)
# edge (61, 12)
# edge (61, 35)
# edge (61, 40)
# edge (61, 49)
# edge (62, 3)
# edge (62, 9)
# edge (62, 33)
# edge (62, 38)
# edge (62, 48)
# edge (62, 71)
# edge (62, 73)
# edge (62, 79)
# edge (62, 94)
# edge (63, 32)
# edge (63, 33)
# edge (63, 43)
# edge (63, 44)
# edge (63, 50)
# edge (63, 54)
# edge (63, 68)
# edge (63, 96)
# edge (63, 98)
# edge (64, 15)
# edge (64, 29)
# edge (64, 31)
# edge (64, 32)
# edge (64, 39)
# edge (64, 52)
# edge (64, 55)
# edge (64, 87)
# edge (64, 96)
# edge (64, 97)
# edge (65, 3)
# edge (65, 7)
# edge (65, 28)
# edge (65, 40)
# edge (65, 52)
# edge (65, 61)
# edge (65, 67)
# edge (65, 93)
# edge (66, 0)
# edge (66, 4)
# edge (66, 11)
# edge (66, 14)
# edge (66, 45)
# edge (66, 62)
# edge (66, 69)
# edge (66, 77)
# edge (66, 79)
# edge (66, 82)
# edge (66, 91)
# edge (66, 94)
# edge (66, 95)
# edge (67, 7)
# edge (67, 31)
# edge (67, 59)
# edge (67, 74)
# edge (67, 87)
# edge (68, 24)
# edge (68, 34)
# edge (68, 36)
# edge (68, 41)
# edge (68, 48)
# edge (68, 60)
# edge (68, 70)
# edge (68, 72)
# edge (68, 83)
# edge (68, 84)
# edge (68, 93)
# edge (68, 95)
# edge (69, 4)
# edge (69, 10)
# edge (69, 13)
# edge (69, 18)
# edge (69, 39)
# edge (69, 58)
# edge (69, 71)
# edge (69, 87)
# edge (70, 15)
# edge (70, 34)
# edge (70, 42)
# edge (70, 48)
# edge (70, 84)
# edge (70, 88)
# edge (71, 18)
# edge (71, 25)
# edge (71, 39)
# edge (71, 43)
# edge (71, 54)
# edge (71, 69)
# edge (71, 73)
# edge (71, 87)
# edge (71, 89)
# edge (72, 2)
# edge (72, 14)
# edge (72, 19)
# edge (72, 36)
# edge (72, 38)
# edge (72, 39)
# edge (72, 47)
# edge (72, 48)
# edge (72, 57)
# edge (72, 73)
# edge (72, 86)
# edge (73, 6)
# edge (73, 7)
# edge (73, 8)
# edge (73, 30)
# edge (73, 48)
# edge (73, 52)
# edge (73, 54)
# edge (73, 66)
# edge (73, 83)
# edge (73, 89)
# edge (73, 93)
# edge (74, 2)
# edge (74, 25)
# edge (74, 30)
# edge (74, 49)
# edge (74, 55)
# edge (74, 64)
# edge (74, 68)
# edge (74, 82)
# edge (74, 83)
# edge (74, 85)
# edge (74, 93)
# edge (74, 96)
# edge (74, 97)
# edge (75, 1)
# edge (75, 2)
# edge (75, 6)
# edge (75, 38)
# edge (75, 39)
# edge (75, 44)
# edge (75, 52)
# edge (75, 76)
# edge (75, 80)
# edge (75, 81)
# edge (76, 3)
# edge (76, 9)
# edge (76, 15)
# edge (76, 24)
# edge (76, 25)
# edge (76, 28)
# edge (76, 44)
# edge (76, 48)
# edge (76, 84)
# edge (76, 98)
# edge (76, 99)
# edge (77, 7)
# edge (77, 12)
# edge (77, 17)
# edge (77, 20)
# edge (77, 29)
# edge (77, 54)
# edge (77, 61)
# edge (77, 71)
# edge (77, 73)
# edge (77, 87)
# edge (77, 94)
# edge (77, 97)
# edge (77, 99)
# edge (78, 3)
# edge (78, 19)
# edge (78, 26)
# edge (78, 56)
# edge (78, 64)
# edge (78, 65)
# edge (78, 71)
# edge (78, 86)
# edge (78, 90)
# edge (79, 12)
# edge (79, 13)
# edge (79, 28)
# edge (79, 57)
# edge (79, 66)
# edge (79, 72)
# edge (79, 98)
# edge (80, 16)
# edge (80, 17)
# edge (80, 26)
# edge (80, 32)
# edge (80, 40)
# edge (80, 56)
# edge (80, 62)
# edge (80, 66)
# edge (80, 72)
# edge (80, 78)
# edge (80, 89)
# edge (80, 99)
# edge (81, 11)
# edge (81, 17)
# edge (81, 48)
# edge (81, 68)
# edge (81, 86)
# edge (82, 10)
# edge (82, 16)
# edge (82, 39)
# edge (82, 47)
# edge (82, 65)
# edge (82, 78)
# edge (82, 80)
# edge (82, 96)
# edge (83, 6)
# edge (83, 27)
# edge (83, 29)
# edge (83, 34)
# edge (83, 46)
# edge (83, 51)
# edge (83, 57)
# edge (83, 65)
# edge (83, 68)
# edge (83, 69)
# edge (83, 77)
# edge (84, 6)
# edge (84, 23)
# edge (84, 32)
# edge (84, 47)
# edge (84, 58)
# edge (84, 60)
# edge (84, 61)
# edge (84, 71)
# edge (84, 76)
# edge (85, 22)
# edge (85, 38)
# edge (85, 63)
# edge (85, 65)
# edge (85, 70)
# edge (85, 74)
# edge (85, 83)
# edge (85, 87)
# edge (85, 90)
# edge (85, 95)
# edge (85, 96)
# edge (85, 97)
# edge (86, 1)
# edge (86, 9)
# edge (86, 16)
# edge (86, 83)
# edge (87, 0)
# edge (87, 15)
# edge (87, 18)
# edge (87, 25)
# edge (87, 49)
# edge (87, 71)
# edge (87, 81)
# edge (87, 86)
# edge (87, 93)
# edge (88, 2)
# edge (88, 22)
# edge (88, 31)
# edge (88, 43)
# edge (88, 49)
# edge (88, 51)
# edge (88, 63)
# edge (88, 65)
# edge (88, 67)
# edge (88, 84)
# edge (89, 2)
# edge (89, 3)
# edge (89, 6)
# edge (89, 9)
# edge (89, 29)
# edge (89, 40)
# edge (89, 50)
# edge (89, 66)
# edge (89, 73)
# edge (89, 77)
# edge (89, 88)
# edge (89, 93)
# edge (89, 95)
# edge (90, 31)
# edge (90, 35)
# edge (90, 37)
# edge (90, 57)
# edge (90, 69)
# edge (90, 74)
# edge (90, 79)
# edge (90, 81)
# edge (90, 92)
# edge (90, 96)
# edge (91, 12)
# edge (91, 14)
# edge (91, 15)
# edge (91, 16)
# edge (91, 27)
# edge (91, 37)
# edge (91, 43)
# edge (91, 53)
# edge (91, 54)
# edge (91, 59)
# edge (91, 78)
# edge (91, 84)
# edge (91, 85)
# edge (91, 93)
# edge (91, 94)
# edge (92, 5)
# edge (92, 13)
# edge (92, 15)
# edge (92, 18)
# edge (92, 20)
# edge (92, 23)
# edge (92, 28)
# edge (92, 30)
# edge (92, 38)
# edge (92, 39)
# edge (92, 44)
# edge (92, 65)
# edge (92, 79)
# edge (92, 82)
# edge (92, 84)
# edge (92, 85)
# edge (92, 86)
# edge (92, 99)
# edge (93, 5)
# edge (93, 20)
# edge (93, 45)
# edge (93, 52)
# edge (93, 56)
# edge (93, 58)
# edge (93, 77)
# edge (93, 87)
# edge (94, 11)
# edge (94, 21)
# edge (94, 47)
# edge (94, 58)
# edge (94, 61)
# edge (94, 62)
# edge (94, 66)
# edge (94, 67)
# edge (94, 69)
# edge (94, 74)
# edge (94, 79)
# edge (94, 82)
# edge (95, 4)
# edge (95, 8)
# edge (95, 20)
# edge (95, 33)
# edge (95, 35)
# edge (95, 42)
# edge (95, 61)
# edge (95, 79)
# edge (95, 90)
# edge (95, 91)
# edge (96, 6)
# edge (96, 12)
# edge (96, 14)
# edge (96, 21)
# edge (96, 39)
# edge (96, 47)
# edge (96, 55)
# edge (96, 61)
# edge (96, 65)
# edge (96, 66)
# edge (96, 67)
# edge (96, 98)
# edge (97, 4)
# edge (97, 14)
# edge (97, 52)
# edge (97, 55)
# edge (97, 73)
# edge (97, 75)
# edge (97, 80)
# edge (97, 85)
# edge (97, 88)
# edge (97, 89)
# edge (97, 90)
# edge (98, 3)
# edge (98, 24)
# edge (98, 57)
# edge (98, 89)
# edge (98, 93)
# edge (99, 33)
# edge (99, 37)
# edge (99, 48)
# edge (99, 52)
# edge (99, 56)
# edge (99, 57)
# edge (99, 61)
# edge (99, 66)
# edge (99, 72)
# edge (99, 73)
# edge (99, 83)
# edge (99, 88)
# edge (99, 93)

# %%
# kenarlari dugumlerle caprazla
for NI in G2.Nodes():
    for Id in NI.GetOutEdges():
        print("edge (%d %d)" % (NI.GetId(), Id))
# Out:
# edge (0 24)
# edge (0 37)
# edge (0 40)
# edge (0 41)
# edge (0 44)
# edge (0 48)
# edge (0 84)
# edge (0 87)
# edge (0 90)
# edge (0 91)
# edge (0 94)
# edge (0 95)
# edge (0 96)
# edge (1 2)
# edge (1 35)
# edge (1 56)
# edge (1 66)
# edge (1 83)
# edge (1 85)
# edge (1 90)
# edge (1 95)
# edge (2 0)
# edge (2 10)
# edge (2 13)
# edge (2 26)
# edge (2 34)
# edge (2 43)
# edge (2 46)
# edge (2 65)
# edge (2 75)
# edge (2 79)
# edge (2 88)
# edge (2 89)
# edge (2 91)
# edge (2 92)
# edge (3 16)
# edge (3 29)
# edge (3 32)
# edge (3 33)
# edge (3 41)
# edge (3 53)
# edge (3 62)
# edge (3 70)
# edge (3 72)
# edge (3 77)
# edge (3 82)
# edge (3 89)
# edge (3 92)
# edge (3 98)
# edge (4 13)
# edge (4 18)
# edge (4 22)
# edge (4 25)
# edge (4 40)
# edge (4 62)
# edge (4 68)
# edge (4 79)
# edge (4 85)
# edge (4 86)
# edge (4 88)
# edge (5 0)
# edge (5 24)
# edge (5 29)
# edge (5 33)
# edge (5 34)
# edge (5 50)
# edge (5 54)
# edge (5 62)
# edge (5 71)
# edge (5 96)
# edge (5 97)
# edge (5 99)
# edge (6 34)
# edge (6 42)
# edge (6 57)
# edge (6 63)
# edge (6 68)
# edge (6 73)
# edge (6 77)
# edge (6 85)
# edge (6 87)
# edge (6 95)
# edge (6 96)
# edge (7 8)
# edge (7 34)
# edge (7 36)
# edge (7 43)
# edge (7 53)
# edge (7 61)
# edge (7 62)
# edge (7 71)
# edge (7 78)
# edge (7 85)
# edge (7 99)
# edge (8 21)
# edge (8 36)
# edge (8 39)
# edge (8 54)
# edge (8 59)
# edge (8 67)
# edge (8 79)
# edge (8 87)
# edge (9 17)
# edge (9 29)
# edge (9 39)
# edge (9 41)
# edge (9 45)
# edge (9 48)
# edge (9 77)
# edge (9 91)
# edge (10 24)
# edge (10 29)
# edge (10 39)
# edge (10 40)
# edge (10 47)
# edge (10 76)
# edge (10 92)
# edge (11 2)
# edge (11 49)
# edge (11 53)
# edge (11 59)
# edge (11 65)
# edge (11 76)
# edge (12 1)
# edge (12 2)
# edge (12 8)
# edge (12 20)
# edge (12 36)
# edge (12 46)
# edge (12 61)
# edge (12 74)
# edge (12 85)
# edge (12 86)
# edge (12 95)
# edge (13 14)
# edge (13 42)
# edge (13 46)
# edge (13 53)
# edge (13 55)
# edge (13 57)
# edge (13 69)
# edge (13 91)
# edge (13 98)
# edge (14 1)
# edge (14 3)
# edge (14 34)
# edge (14 37)
# edge (14 54)
# edge (14 57)
# edge (14 66)
# edge (14 78)
# edge (14 79)
# edge (15 7)
# edge (15 8)
# edge (15 16)
# edge (15 22)
# edge (15 36)
# edge (15 40)
# edge (15 45)
# edge (15 48)
# edge (15 65)
# edge (15 96)
# edge (15 97)
# edge (16 14)
# edge (16 15)
# edge (16 21)
# edge (16 29)
# edge (16 37)
# edge (16 42)
# edge (16 48)
# edge (16 62)
# edge (16 73)
# edge (16 78)
# edge (16 96)
# edge (17 2)
# edge (17 6)
# edge (17 19)
# edge (17 39)
# edge (17 40)
# edge (17 61)
# edge (17 72)
# edge (18 0)
# edge (18 11)
# edge (18 17)
# edge (18 20)
# edge (18 32)
# edge (18 76)
# edge (18 80)
# edge (18 86)
# edge (19 1)
# edge (19 7)
# edge (19 23)
# edge (19 25)
# edge (19 26)
# edge (19 38)
# edge (19 66)
# edge (19 70)
# edge (19 72)
# edge (19 79)
# edge (19 93)
# edge (20 2)
# edge (20 13)
# edge (20 28)
# edge (20 32)
# edge (20 37)
# edge (20 46)
# edge (20 53)
# edge (20 59)
# edge (20 78)
# edge (20 79)
# edge (20 80)
# edge (20 92)
# edge (20 94)
# edge (21 0)
# edge (21 2)
# edge (21 8)
# edge (21 18)
# edge (21 40)
# edge (21 47)
# edge (21 48)
# edge (21 50)
# edge (21 51)
# edge (21 56)
# edge (21 70)
# edge (21 73)
# edge (21 83)
# edge (22 1)
# edge (22 2)
# edge (22 7)
# edge (22 9)
# edge (22 19)
# edge (22 24)
# edge (22 30)
# edge (22 71)
# edge (22 75)
# edge (22 87)
# edge (22 92)
# edge (23 39)
# edge (23 43)
# edge (23 51)
# edge (23 52)
# edge (23 75)
# edge (23 84)
# edge (23 88)
# edge (23 98)
# edge (24 8)
# edge (24 10)
# edge (24 41)
# edge (24 56)
# edge (24 68)
# edge (24 76)
# edge (24 77)
# edge (24 80)
# edge (24 98)
# edge (25 2)
# edge (25 16)
# edge (25 24)
# edge (25 29)
# edge (25 47)
# edge (25 50)
# edge (25 55)
# edge (25 75)
# edge (25 80)
# edge (25 98)
# edge (26 14)
# edge (26 15)
# edge (26 20)
# edge (26 54)
# edge (26 68)
# edge (26 70)
# edge (26 79)
# edge (26 88)
# edge (27 1)
# edge (27 3)
# edge (27 8)
# edge (27 28)
# edge (27 29)
# edge (27 32)
# edge (27 33)
# edge (27 47)
# edge (27 49)
# edge (27 57)
# edge (27 60)
# edge (27 70)
# edge (27 92)
# edge (28 1)
# edge (28 13)
# edge (28 18)
# edge (28 21)
# edge (28 29)
# edge (28 42)
# edge (28 74)
# edge (28 87)
# edge (28 99)
# edge (29 15)
# edge (29 52)
# edge (29 54)
# edge (29 81)
# edge (29 90)
# edge (29 96)
# edge (29 99)
# edge (30 38)
# edge (30 61)
# edge (30 85)
# edge (31 0)
# edge (31 7)
# edge (31 9)
# edge (31 21)
# edge (31 23)
# edge (31 25)
# edge (31 42)
# edge (31 50)
# edge (31 67)
# edge (31 77)
# edge (31 83)
# edge (31 86)
# edge (32 11)
# edge (32 19)
# edge (32 30)
# edge (32 37)
# edge (32 41)
# edge (32 44)
# edge (32 49)
# edge (32 50)
# edge (32 51)
# edge (32 55)
# edge (32 60)
# edge (32 61)
# edge (32 83)
# edge (32 85)
# edge (32 91)
# edge (32 93)
# edge (32 97)
# edge (33 7)
# edge (33 22)
# edge (33 35)
# edge (33 40)
# edge (33 41)
# edge (33 53)
# edge (33 80)
# edge (33 89)
# edge (33 98)
# edge (34 1)
# edge (34 2)
# edge (34 7)
# edge (34 20)
# edge (34 43)
# edge (34 44)
# edge (34 57)
# edge (34 63)
# edge (34 64)
# edge (34 69)
# edge (34 86)
# edge (34 87)
# edge (34 88)
# edge (34 93)
# edge (35 18)
# edge (35 24)
# edge (35 26)
# edge (35 27)
# edge (35 30)
# edge (35 45)
# edge (35 65)
# edge (35 66)
# edge (35 72)
# edge (35 79)
# edge (36 14)
# edge (36 20)
# edge (36 32)
# edge (36 42)
# edge (36 50)
# edge (36 52)
# edge (36 71)
# edge (36 99)
# edge (37 9)
# edge (37 16)
# edge (37 22)
# edge (37 23)
# edge (37 30)
# edge (37 32)
# edge (37 47)
# edge (37 63)
# edge (37 66)
# edge (37 67)
# edge (37 71)
# edge (37 79)
# edge (37 91)
# edge (38 32)
# edge (38 34)
# edge (38 36)
# edge (38 67)
# edge (38 93)
# edge (39 9)
# edge (39 12)
# edge (39 18)
# edge (39 28)
# edge (39 38)
# edge (39 42)
# edge (39 44)
# edge (39 48)
# edge (39 53)
# edge (39 54)
# edge (39 58)
# edge (39 61)
# edge (39 65)
# edge (39 66)
# edge (39 70)
# edge (39 83)
# edge (39 95)
# edge (39 97)
# edge (40 2)
# edge (40 6)
# edge (40 21)
# edge (40 34)
# edge (40 58)
# edge (40 72)
# edge (40 84)
# edge (40 85)
# edge (41 40)
# edge (41 43)
# edge (41 44)
# edge (41 53)
# edge (41 89)
# edge (41 96)
# edge (42 0)
# edge (42 5)
# edge (42 6)
# edge (42 14)
# edge (42 18)
# edge (42 20)
# edge (42 26)
# edge (42 40)
# edge (42 56)
# edge (42 76)
# edge (43 16)
# edge (43 30)
# edge (43 79)
# edge (44 12)
# edge (44 64)
# edge (44 68)
# edge (44 69)
# edge (44 72)
# edge (44 97)
# edge (45 3)
# edge (45 10)
# edge (45 18)
# edge (45 19)
# edge (45 24)
# edge (45 26)
# edge (45 32)
# edge (45 34)
# edge (45 41)
# edge (45 46)
# edge (45 63)
# edge (45 79)
# edge (45 80)
# edge (45 82)
# edge (45 85)
# edge (45 90)
# edge (46 7)
# edge (46 16)
# edge (46 39)
# edge (46 47)
# edge (46 63)
# edge (46 69)
# edge (46 80)
# edge (46 85)
# edge (47 33)
# edge (47 38)
# edge (47 43)
# edge (47 46)
# edge (47 65)
# edge (47 72)
# edge (47 78)
# edge (47 91)
# edge (47 96)
# edge (48 3)
# edge (48 5)
# edge (48 14)
# edge (48 17)
# edge (48 33)
# edge (48 50)
# edge (48 51)
# edge (48 54)
# edge (48 66)
# edge (48 70)
# edge (48 71)
# edge (48 76)
# edge (48 77)
# edge (48 84)
# edge (48 96)
# edge (48 98)
# edge (49 12)
# edge (49 20)
# edge (49 27)
# edge (49 35)
# edge (49 39)
# edge (49 61)
# edge (49 75)
# edge (49 76)
# edge (49 87)
# edge (49 96)
# edge (50 6)
# edge (50 12)
# edge (50 19)
# edge (50 25)
# edge (50 32)
# edge (50 37)
# edge (50 44)
# edge (50 57)
# edge (50 61)
# edge (50 69)
# edge (50 80)
# edge (50 90)
# edge (50 95)
# edge (50 98)
# edge (50 99)
# edge (51 33)
# edge (51 39)
# edge (51 75)
# edge (51 76)
# edge (51 81)
# edge (51 95)
# edge (52 1)
# edge (52 14)
# edge (52 27)
# edge (52 30)
# edge (52 33)
# edge (52 37)
# edge (52 44)
# edge (52 51)
# edge (52 59)
# edge (52 66)
# edge (52 67)
# edge (52 74)
# edge (52 85)
# edge (52 98)
# edge (53 5)
# edge (53 22)
# edge (53 28)
# edge (53 34)
# edge (53 45)
# edge (53 48)
# edge (53 49)
# edge (53 56)
# edge (53 57)
# edge (53 61)
# edge (53 66)
# edge (53 69)
# edge (53 71)
# edge (53 85)
# edge (53 90)
# edge (54 10)
# edge (54 33)
# edge (54 41)
# edge (54 45)
# edge (54 49)
# edge (54 51)
# edge (54 76)
# edge (54 82)
# edge (54 96)
# edge (55 8)
# edge (55 19)
# edge (55 41)
# edge (55 49)
# edge (55 50)
# edge (55 60)
# edge (55 77)
# edge (56 6)
# edge (56 12)
# edge (56 51)
# edge (56 59)
# edge (56 68)
# edge (56 75)
# edge (56 82)
# edge (56 89)
# edge (57 8)
# edge (57 28)
# edge (57 37)
# edge (57 42)
# edge (57 48)
# edge (57 61)
# edge (57 75)
# edge (57 78)
# edge (57 85)
# edge (57 94)
# edge (57 97)
# edge (58 5)
# edge (58 6)
# edge (58 9)
# edge (58 11)
# edge (58 15)
# edge (58 16)
# edge (58 19)
# edge (58 55)
# edge (58 63)
# edge (58 64)
# edge (58 69)
# edge (58 91)
# edge (58 95)
# edge (58 98)
# edge (59 28)
# edge (59 32)
# edge (59 37)
# edge (59 38)
# edge (59 47)
# edge (60 14)
# edge (60 17)
# edge (60 22)
# edge (60 26)
# edge (60 57)
# edge (60 69)
# edge (60 85)
# edge (60 86)
# edge (61 0)
# edge (61 12)
# edge (61 35)
# edge (61 40)
# edge (61 49)
# edge (62 3)
# edge (62 9)
# edge (62 33)
# edge (62 38)
# edge (62 48)
# edge (62 71)
# edge (62 73)
# edge (62 79)
# edge (62 94)
# edge (63 32)
# edge (63 33)
# edge (63 43)
# edge (63 44)
# edge (63 50)
# edge (63 54)
# edge (63 68)
# edge (63 96)
# edge (63 98)
# edge (64 15)
# edge (64 29)
# edge (64 31)
# edge (64 32)
# edge (64 39)
# edge (64 52)
# edge (64 55)
# edge (64 87)
# edge (64 96)
# edge (64 97)
# edge (65 3)
# edge (65 7)
# edge (65 28)
# edge (65 40)
# edge (65 52)
# edge (65 61)
# edge (65 67)
# edge (65 93)
# edge (66 0)
# edge (66 4)
# edge (66 11)
# edge (66 14)
# edge (66 45)
# edge (66 62)
# edge (66 69)
# edge (66 77)
# edge (66 79)
# edge (66 82)
# edge (66 91)
# edge (66 94)
# edge (66 95)
# edge (67 7)
# edge (67 31)
# edge (67 59)
# edge (67 74)
# edge (67 87)
# edge (68 24)
# edge (68 34)
# edge (68 36)
# edge (68 41)
# edge (68 48)
# edge (68 60)
# edge (68 70)
# edge (68 72)
# edge (68 83)
# edge (68 84)
# edge (68 93)
# edge (68 95)
# edge (69 4)
# edge (69 10)
# edge (69 13)
# edge (69 18)
# edge (69 39)
# edge (69 58)
# edge (69 71)
# edge (69 87)
# edge (70 15)
# edge (70 34)
# edge (70 42)
# edge (70 48)
# edge (70 84)
# edge (70 88)
# edge (71 18)
# edge (71 25)
# edge (71 39)
# edge (71 43)
# edge (71 54)
# edge (71 69)
# edge (71 73)
# edge (71 87)
# edge (71 89)
# edge (72 2)
# edge (72 14)
# edge (72 19)
# edge (72 36)
# edge (72 38)
# edge (72 39)
# edge (72 47)
# edge (72 48)
# edge (72 57)
# edge (72 73)
# edge (72 86)
# edge (73 6)
# edge (73 7)
# edge (73 8)
# edge (73 30)
# edge (73 48)
# edge (73 52)
# edge (73 54)
# edge (73 66)
# edge (73 83)
# edge (73 89)
# edge (73 93)
# edge (74 2)
# edge (74 25)
# edge (74 30)
# edge (74 49)
# edge (74 55)
# edge (74 64)
# edge (74 68)
# edge (74 82)
# edge (74 83)
# edge (74 85)
# edge (74 93)
# edge (74 96)
# edge (74 97)
# edge (75 1)
# edge (75 2)
# edge (75 6)
# edge (75 38)
# edge (75 39)
# edge (75 44)
# edge (75 52)
# edge (75 76)
# edge (75 80)
# edge (75 81)
# edge (76 3)
# edge (76 9)
# edge (76 15)
# edge (76 24)
# edge (76 25)
# edge (76 28)
# edge (76 44)
# edge (76 48)
# edge (76 84)
# edge (76 98)
# edge (76 99)
# edge (77 7)
# edge (77 12)
# edge (77 17)
# edge (77 20)
# edge (77 29)
# edge (77 54)
# edge (77 61)
# edge (77 71)
# edge (77 73)
# edge (77 87)
# edge (77 94)
# edge (77 97)
# edge (77 99)
# edge (78 3)
# edge (78 19)
# edge (78 26)
# edge (78 56)
# edge (78 64)
# edge (78 65)
# edge (78 71)
# edge (78 86)
# edge (78 90)
# edge (79 12)
# edge (79 13)
# edge (79 28)
# edge (79 57)
# edge (79 66)
# edge (79 72)
# edge (79 98)
# edge (80 16)
# edge (80 17)
# edge (80 26)
# edge (80 32)
# edge (80 40)
# edge (80 56)
# edge (80 62)
# edge (80 66)
# edge (80 72)
# edge (80 78)
# edge (80 89)
# edge (80 99)
# edge (81 11)
# edge (81 17)
# edge (81 48)
# edge (81 68)
# edge (81 86)
# edge (82 10)
# edge (82 16)
# edge (82 39)
# edge (82 47)
# edge (82 65)
# edge (82 78)
# edge (82 80)
# edge (82 96)
# edge (83 6)
# edge (83 27)
# edge (83 29)
# edge (83 34)
# edge (83 46)
# edge (83 51)
# edge (83 57)
# edge (83 65)
# edge (83 68)
# edge (83 69)
# edge (83 77)
# edge (84 6)
# edge (84 23)
# edge (84 32)
# edge (84 47)
# edge (84 58)
# edge (84 60)
# edge (84 61)
# edge (84 71)
# edge (84 76)
# edge (85 22)
# edge (85 38)
# edge (85 63)
# edge (85 65)
# edge (85 70)
# edge (85 74)
# edge (85 83)
# edge (85 87)
# edge (85 90)
# edge (85 95)
# edge (85 96)
# edge (85 97)
# edge (86 1)
# edge (86 9)
# edge (86 16)
# edge (86 83)
# edge (87 0)
# edge (87 15)
# edge (87 18)
# edge (87 25)
# edge (87 49)
# edge (87 71)
# edge (87 81)
# edge (87 86)
# edge (87 93)
# edge (88 2)
# edge (88 22)
# edge (88 31)
# edge (88 43)
# edge (88 49)
# edge (88 51)
# edge (88 63)
# edge (88 65)
# edge (88 67)
# edge (88 84)
# edge (89 2)
# edge (89 3)
# edge (89 6)
# edge (89 9)
# edge (89 29)
# edge (89 40)
# edge (89 50)
# edge (89 66)
# edge (89 73)
# edge (89 77)
# edge (89 88)
# edge (89 93)
# edge (89 95)
# edge (90 31)
# edge (90 35)
# edge (90 37)
# edge (90 57)
# edge (90 69)
# edge (90 74)
# edge (90 79)
# edge (90 81)
# edge (90 92)
# edge (90 96)
# edge (91 12)
# edge (91 14)
# edge (91 15)
# edge (91 16)
# edge (91 27)
# edge (91 37)
# edge (91 43)
# edge (91 53)
# edge (91 54)
# edge (91 59)
# edge (91 78)
# edge (91 84)
# edge (91 85)
# edge (91 93)
# edge (91 94)
# edge (92 5)
# edge (92 13)
# edge (92 15)
# edge (92 18)
# edge (92 20)
# edge (92 23)
# edge (92 28)
# edge (92 30)
# edge (92 38)
# edge (92 39)
# edge (92 44)
# edge (92 65)
# edge (92 79)
# edge (92 82)
# edge (92 84)
# edge (92 85)
# edge (92 86)
# edge (92 99)
# edge (93 5)
# edge (93 20)
# edge (93 45)
# edge (93 52)
# edge (93 56)
# edge (93 58)
# edge (93 77)
# edge (93 87)
# edge (94 11)
# edge (94 21)
# edge (94 47)
# edge (94 58)
# edge (94 61)
# edge (94 62)
# edge (94 66)
# edge (94 67)
# edge (94 69)
# edge (94 74)
# edge (94 79)
# edge (94 82)
# edge (95 4)
# edge (95 8)
# edge (95 20)
# edge (95 33)
# edge (95 35)
# edge (95 42)
# edge (95 61)
# edge (95 79)
# edge (95 90)
# edge (95 91)
# edge (96 6)
# edge (96 12)
# edge (96 14)
# edge (96 21)
# edge (96 39)
# edge (96 47)
# edge (96 55)
# edge (96 61)
# edge (96 65)
# edge (96 66)
# edge (96 67)
# edge (96 98)
# edge (97 4)
# edge (97 14)
# edge (97 52)
# edge (97 55)
# edge (97 73)
# edge (97 75)
# edge (97 80)
# edge (97 85)
# edge (97 88)
# edge (97 89)
# edge (97 90)
# edge (98 3)
# edge (98 24)
# edge (98 57)
# edge (98 89)
# edge (98 93)
# edge (99 33)
# edge (99 37)
# edge (99 48)
# edge (99 52)
# edge (99 56)
# edge (99 57)
# edge (99 61)
# edge (99 66)
# edge (99 72)
# edge (99 73)
# edge (99 83)
# edge (99 88)
# edge (99 93)

# %% [markdown]
# Genel olarak düğüm yineleyicileri aşağıdaki işlevleri sağlar:
#
# - GetId(): dönüş düğümü kimliği
# - GetOutDeg(): bir düğümün çıkış derecesini döndürür
# - GetInDeg(): bir düğümün derecesini döndürür
# - GetOutNId(e): e-th out-edge'nin uç noktasının düğüm kimliğini döndürür
# - GetInNId(e): e-th in-edge'nin uç noktasının düğüm kimliğini döndürür
# - IsOutNId(int NId): düğüm kimliği n'yi işaret ediyor muyuz?
# - IsInNId(n): düğüm kimliği n bizi işaret ediyor mu?
# - IsNbrNId(n): komşumuz olan düğüm

# %% [markdown]
# ---

# %% [markdown]
# ### Input/Output:
# SNAP ile ağları çeşitli biçimlerde kaydetmek ve yüklemek kolaydır. Dahili olarak SNAP, ağları kompakt ikili biçimde kaydeder, ancak ağları diğer çeşitli metin ve XML biçimlerinde yüklemek ve kaydetmek için işlevler de mevcuttur.
#
# Örneğin, grafikleri kaydetmek ve yüklemek için Snap.py kodu aşağıdaki gibi görünür:

# %%
# Forest Fire modeli kullanarak ag olusturmak
G3 = snap.GenForestFire(1000, 0.35, 0.35)

# %%
# ikili kaydetme ve yukleme
FOut = snap.TFOut("test.graph")
G3.Save(FOut)
FOut.Flush()
FIn = snap.TFIn("test.graph")
G4 = snap.TNGraph.Load(FIn)

# %%
# bir metin dosyasindan kaydetme ve yukleme
snap.SaveEdgeList(G4, "test.txt", "Save as tab-separated list of edges")
G5 = snap.LoadEdgeList(snap.TNGraph, "test.txt", 0, 1)

# %% [markdown]
# ---

# %% [markdown]
# ### Grafikleri ve Ağları Manipüle Etme:
# SNAP, grafikleri ve ağları verimli bir şekilde işlemek için zengin işlevsellik sağlar. Çoğu işlev, tüm grafik/ağ türlerini destekler.
#
# Örneğin:

# %%
# Forest Fire modeli kullanarak ag olusturmak
G6 = snap.GenForestFire(1000, 0.35, 0.35)

# %%
# yonsuz grafige donustur
G7 = G6.ConvertGraph(snap.TUNGraph)
WccG = G6.GetMxWcc()

# %%
# [0,1,2,3,4,5] düğümlerinde indüklenen bir alt grafik elde edin
SubG = G6.GetSubGraph([0,1,2,3,4])

# %%
# 3 çekirdekli G elde edin
Core3 = G6.GetKCore(3)

# %%
# 10. dereceden ve 5. dereceden düğümleri sil
G6.DelDegKNodes(10, 5)

# %% [markdown]
# ---

# %% [markdown]
# ### Ağların Hesaplama Yapısal Özellikleri:
# SNAP, ağların yapısal özelliklerini verimli bir şekilde hesaplamak için zengin işlevsellik sağlar. Çoğu işlev, tüm grafik/ağ türlerini destekler.
#
# Örneğin:

# %%
# 1000 düğümde bir Preferential Attachment grafiği oluşturun ve düğüm çıkış derecesi 3
G8 = snap.GenPrefAttach(1000, 3)

# %%
# bağlı bileşenlerin dağıtımını alın (bileşen boyutu, sayısı)
CntV = G8.GetWccSzCnt()

# %%
# derece dağıtım çiftlerini al (derece, sayı)
CntV = G8.GetOutDegCnt()

# %%
# grafik komşuluk matrisinin ilk özvektörünü al
EigV = G8.GetLeadEigVec()

# %%
# G8 çapını al
G8.GetBfsFullDiam(100)
# Out:
# 6

# %%
# G8'deki triad sayısını sayın, G8'in kümeleme katsayısını elde edin
G8.GetTriads()
G8.GetClustCf()
# Out:
# 0.02851417689038774
